# %% [markdown]
# # Маркетинговый анализ приложения Procrastinate Pro+

# %% [markdown]
# **Описание проекта**
#
# Вы — маркетинговый аналитик развлекательного приложения Procrastinate Pro+. Несмотря на огромные вложения в рекламу, последние несколько месяцев компания терпит убытки. Ваша задача — разобраться в причинах и помочь компании выйти в плюс.
#
# Есть данные о пользователях, привлечённых с 1 мая по 27 октября 2019 года:
# - лог сервера с данными об их посещениях,
# - выгрузка их покупок за этот период,
# - рекламные расходы.
#
# Вам предстоит изучить:
# - откуда приходят пользователи и какими устройствами они пользуются,
# - сколько стоит привлечение пользователей из различных рекламных каналов;
# - сколько денег приносит каждый клиент,
# - когда расходы на привлечение клиента окупаются,
# - какие факторы мешают привлечению клиентов.

# %% [markdown]
# **Описание данных**
#
# В вашем распоряжении три датасета. Файл visits_info_short.csv хранит лог сервера с информацией о посещениях сайта, orders_info_short.csv — информацию о заказах, а costs_info_short.csv — информацию о расходах на рекламу.
#
# Структура visits_info_short.csv:
# - User Id — уникальный идентификатор пользователя,
# - Region — страна пользователя,
# - Device — тип устройства пользователя,
# - Channel — идентификатор источника перехода,
# - Session Start — дата и время начала сессии,
# - Session End — дата и время окончания сессии.
#
# Структура orders_info_short.csv:
# - User Id — уникальный идентификатор пользователя,
# - Event Dt — дата и время покупки,
# - Revenue — сумма заказа.
#
# Структура costs_info_short.csv:
# - dt — дата проведения рекламной кампании,
# - Channel — идентификатор рекламного источника,
# - costs — расходы на эту кампанию.

# %% [markdown]
# **План работы:**
#
# 1. Загрузить данные и подготовить их к анализу
# 2. Задать функции для расчёта и анализа LTV, ROI, удержания и конверсии
# 3. Исследовательский анализ данных</br>
#     3.1 Составить профили пользователей. Определить минимальную и максимальную даты привлечения пользователей.</br>
#     3.2 Выяснить, из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей. Построить таблицу, отражающую количество пользователей и долю платящих из каждой страны. </br>
#     3.3 Узнать, какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи. Построить таблицу, отражающую количество пользователей и долю платящих для каждого устройства.</br>
#     3.4 Изучить рекламные источники привлечения и определите каналы, из которых пришло больше всего платящих пользователей. Построить таблицу, отражающую количество пользователей и долю платящих для каждого канала привлечения. </br>
# 4. Маркетинг </br>
#     4.1 Посчитать общую сумму расходов на маркетинг.</br>
#     4.2 Выяснить, как траты распределены по рекламным источникам, то есть сколько денег потратили на каждый источник.</br>
#     4.3 Построить график с визуализацией динамики изменения расходов во времени по неделям по каждому источнику. Затем на другом графике визуализировать динамику изменения расходов во времени по месяцам по каждому источнику.</br>
#     4.4 Узнать, сколько в среднем стоило привлечение одного пользователя (CAC) из каждого источника. Использовать профили пользователей.</br>
# 5. Оценить окупаемость рекламы </br>
#     5.1 Проанализировать окупаемость рекламы c помощью графиков LTV и ROI, а также графики динамики LTV, CAC и ROI.</br>
#     5.2 Проверить конверсию пользователей и динамику её изменения. То же самое сделать с удержанием пользователей. Построить и изучить графики конверсии и удержания с разбивкой по устройствам, странам, рекламным каналам.</br>
#     5.3 Проанализировать окупаемость рекламы с разбивкой по устройствам. Построить графики LTV и ROI, а также графики динамики LTV, CAC и ROI.</br>
#     5.4 Проанализировать окупаемость рекламы с разбивкой по странам. Построить графики LTV и ROI, а также графики динамики LTV, CAC и ROI.</br>
#     5.5 Проанализировать окупаемость рекламы с разбивкой по рекламным каналам. Построить графики LTV и ROI, а также графики динамики LTV, CAC и ROI.</br>
#     5.6 Ответить на такие вопросы:</br>
#         - Окупается ли реклама, направленная на привлечение пользователей в целом?</br>
#         - Какие устройства, страны и рекламные каналы могут оказывать негативное влияние на окупаемость рекламы?</br>
#         - Чем могут быть вызваны проблемы окупаемости?</br>
# 6. Написать выводы</br>
#     6.1 Выделить причины неэффективности привлечения пользователей.</br>
#     6.2 Сформулировать рекомендации для отдела маркетинга.</br>

# %% [markdown]
# ### Загрузим данные и подготовим их к анализу

# %% [markdown]
# Загрузите данные о визитах, заказах и рекламных расходах из CSV-файлов в переменные.
#
# **Пути к файлам**
#
# - визиты: `/datasets/visits_info_short.csv`. [Скачать датасет](https://code.s3.yandex.net/datasets/visits_info_short.csv);
# - заказы: `/datasets/orders_info_short.csv`. [Скачать датасет](https://code.s3.yandex.net/datasets/orders_info_short.csv);
# - расходы: `/datasets/costs_info_short.csv`. [Скачать датасет](https://code.s3.yandex.net/datasets/costs_info_short.csv).
#
# Изучите данные и выполните предобработку. Есть ли в данных пропуски и дубликаты? Убедитесь, что типы данных во всех колонках соответствуют сохранённым в них значениям. Обратите внимание на столбцы с датой и временем.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta
import numpy as np

# %% [markdown]
# Загрузим данные о визитах, заказах и рекламных расходах из CSV-файлов в переменные.

# %%
import os

pth1_1 = '/datasets/visits_info_short.csv'
pth1_2 = 'datasets/visits_info_short.csv'
pth2_1 = '/datasets/orders_info_short.csv'
pth2_2 = 'datasets/orders_info_short.csv'
pth3_1 = '/datasets/costs_info_short.csv'
pth3_2 = 'datasets/costs_info_short.csv'

if os.path.exists(pth1_1):
    visits = pd.read_csv(pth1_1)
    orders = pd.read_csv(pth2_1)
    costs = pd.read_csv(pth3_1)
elif os.path.exists(pth1_2):
    visits = pd.read_csv(pth1_2)
    orders = pd.read_csv(pth2_2)
    costs = pd.read_csv(pth3_2)
else:
    print("Проверьте правильность пути к датасету")

# %% [markdown]
# **Изучим таблицу visits**

# %%
visits.head(10)
# Out:
#         User Id         Region   Device         Channel        Session Start  \
# 0  981449118918  United States   iPhone         organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone         organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac         organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android          TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac         organic  2019-05-01 03:33:35
# 5   90242400005  United States   iPhone  RocketSuperAds  2019-05-01 07:14:52
# 6   43958116050  United States  Android         organic  2019-05-01 09:03:21
# 7  185365244969  United States   iPhone         organic  2019-05-01 09:37:03
# 8  446013509831  United States   iPhone  RocketSuperAds  2019-05-01 10:26:00
# 9  100970711362  United States      Mac          TipTop  2019-05-01 04:39:53
#
#            Session End
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# 3  2019-05-01 00:54:25
# ...

# %%
visits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   User Id        309901 non-null  int64
#  1   Region         309901 non-null  object
#  2   Device         309901 non-null  object
#  3   Channel        309901 non-null  object
#  4   Session Start  309901 non-null  object
#  5   Session End    309901 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB

# %% [markdown]
# Пропусков в таблице нет.

# %% [markdown]
# Переименуем названия столбцов согласно змеиному регистру.

# %%
visits.columns = [x.lower().replace(' ', '_') for x in visits.columns]

# %%
visits.head()
# Out:
#         user_id         region   device  channel        session_start  \
# 0  981449118918  United States   iPhone  organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic  2019-05-01 03:33:35
#
#            session_end
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# 3  2019-05-01 00:54:25
# 4  2019-05-01 03:57:40

# %% [markdown]
# Проверим таблицу на наличие дубликатов.

# %%
visits.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Дубликатов в таблице также нет.

# %% [markdown]
# Пробразуем данные в столбцах `session_start` и `session_end` к типу datetime.

# %%
visits['session_start'] = pd.to_datetime(visits['session_start'])
visits['session_end'] = pd.to_datetime(visits['session_end'])

# %%
visits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   user_id        309901 non-null  int64
#  1   region         309901 non-null  object
#  2   device         309901 non-null  object
#  3   channel        309901 non-null  object
#  4   session_start  309901 non-null  datetime64[ns]
#  5   session_end    309901 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(3)
# memory usage: 14.2+ MB

# %% [markdown]
# **Изучим таблицу orders**

# %%
orders.head(10)
# Out:
#         User Id             Event Dt  Revenue
# 0  188246423999  2019-05-01 23:09:52     4.99
# 1  174361394180  2019-05-01 12:24:04     4.99
# 2  529610067795  2019-05-01 11:34:04     4.99
# 3  319939546352  2019-05-01 15:34:40     4.99
# 4  366000285810  2019-05-01 13:59:51     4.99
# 5  129100331057  2019-05-01 01:56:28     4.99
# 6  626807144131  2019-05-01 02:39:21     4.99
# 7  914062168985  2019-05-01 02:02:18     4.99
# 8  769669137453  2019-05-01 03:39:47     4.99
# 9  434198630691  2019-05-01 18:16:50     5.99

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   User Id   40212 non-null  int64
#  1   Event Dt  40212 non-null  object
#  2   Revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB

# %% [markdown]
# Пропусков нет.

# %% [markdown]
# Теперь проверим наличие дубликатов.

# %%
orders.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Дубликатов нет.

# %% [markdown]
# Переименуем столбцы согласно змеиному регистру.

# %%
orders.columns = ['user_id', 'event_dt', 'revenue']
orders.head()
# Out:
#         user_id             event_dt  revenue
# 0  188246423999  2019-05-01 23:09:52     4.99
# 1  174361394180  2019-05-01 12:24:04     4.99
# 2  529610067795  2019-05-01 11:34:04     4.99
# 3  319939546352  2019-05-01 15:34:40     4.99
# 4  366000285810  2019-05-01 13:59:51     4.99

# %% [markdown]
# Приведем данные в столбце `event_dt` к типу datetime.

# %%
orders['event_dt'] = pd.to_datetime(orders['event_dt'])

orders.info()
orders.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   40212 non-null  int64
#  1   event_dt  40212 non-null  datetime64[ns]
#  2   revenue   40212 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 942.6 KB
#         user_id            event_dt  revenue
# 0  188246423999 2019-05-01 23:09:52     4.99
# 1  174361394180 2019-05-01 12:24:04     4.99
# 2  529610067795 2019-05-01 11:34:04     4.99
# 3  319939546352 2019-05-01 15:34:40     4.99
# 4  366000285810 2019-05-01 13:59:51     4.99

# %% [markdown]
# **Изучим таблицу costs**

# %%
costs.head(10)
# Out:
#            dt   Channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# 2  2019-05-03  FaceBoom   85.8
# 3  2019-05-04  FaceBoom  136.4
# 4  2019-05-05  FaceBoom  122.1
# 5  2019-05-06  FaceBoom  118.8
# 6  2019-05-07  FaceBoom  101.2
# 7  2019-05-08  FaceBoom  100.1
# 8  2019-05-09  FaceBoom   93.5
# 9  2019-05-10  FaceBoom  104.5

# %%
costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   Channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB

# %% [markdown]
# Переименуем столбцы, а также преобразуем тип столбца dt.

# %%
costs.columns = ['dt', 'channel', 'costs']
costs['dt'] = pd.to_datetime(costs['dt'])#.dt.date

costs.info()
costs.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   datetime64[ns]
#  1   channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 42.3+ KB
#           dt   channel  costs
# 0 2019-05-01  FaceBoom  113.3
# 1 2019-05-02  FaceBoom   78.1
# 2 2019-05-03  FaceBoom   85.8
# 3 2019-05-04  FaceBoom  136.4
# 4 2019-05-05  FaceBoom  122.1

# %% [markdown]
# **Выводы по предобработке данных**
#
# 1. Данные в представленных таблицах не имеют пропусков и дубликатов.
# 2. Названия столбцов в таблицах были изменены согласно змеиному регистру.
# 3. Тип данных столбцов `session_start` в таблице visits, `event_dt` в orders, `dt` в costs был привелён к datetime.

# %% [markdown]
# ### Зададим функции для расчёта и анализа LTV, ROI, удержания и конверсии.
#
# Разрешается использовать функции, с которыми вы познакомились в теоретических уроках.
#
# Это функции для вычисления значений метрик:
#
# - `get_profiles()` — для создания профилей пользователей,
# - `get_retention()` — для подсчёта Retention Rate,
# - `get_conversion()` — для подсчёта конверсии,
# - `get_ltv()` — для подсчёта LTV.
#
# А также функции для построения графиков:
#
# - `filter_data()` — для сглаживания данных,
# - `plot_retention()` — для построения графика Retention Rate,
# - `plot_conversion()` — для построения графика конверсии,
# - `plot_ltv_roi` — для визуализации LTV и ROI.

# %% [markdown]
# #### **Зададим функцию для создания профилей**

# %%
# функция для создания пользовательских профилей

def get_profiles(sessions, orders, ad_costs, event_names=[]):

    # находим параметры первых посещений
    profiles = (
        sessions.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].values.astype('datetime64[M]')
    ad_costs['dt'] = ad_costs['dt'].dt.date
    
    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())


    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )

    # объединяем траты на рекламу и число привлечённых пользователей
    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    
    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %% [markdown]
# #### **Зададим функцию для подсчета Retention Rate**

# %%
# функция для расчёта удержания

def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# #### **Зададим функцию для подсчета конверсии**

# %%
# функция для расчёта конверсии

def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# #### **Зададим функцию для подсчета LTV**

# %%
# функция для расчёта LTV и ROI

def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираем датафрейм с данными пользователей и значениями CAC, 
        # добавляя параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# #### **Зададим функцию для сглаживания данных**

# %%
# функция для сглаживания фрейма

def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %% [markdown]
# #### **Зададим функцию для построения графика Retention Rate**

# %%
# функция для визуализации удержания

def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### **Зададим функцию для построения графика конверсии**

# %%
# функция для визуализации конверсии

def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# **Зададим функцию для визуализации LTV и ROI**

# %%
# функция для визуализации LTV и ROI

def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Исследовательский анализ данных
#
# - Составьте профили пользователей. Определите минимальную и максимальную даты привлечения пользователей.
# - Выясните, из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей. Постройте таблицу, отражающую количество пользователей и долю платящих из каждой страны.
# - Узнайте, какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи. Постройте таблицу, отражающую количество пользователей и долю платящих для каждого устройства.
# - Изучите рекламные источники привлечения и определите каналы, из которых пришло больше всего платящих пользователей. Постройте таблицу, отражающую количество пользователей и долю платящих для каждого канала привлечения.
#
# После каждого пункта сформулируйте выводы.

# %% [markdown]
# Составим профили пользователей.

# %%
profiles = get_profiles(sessions=visits, orders=orders, ad_costs=costs)
costs['dt'] = pd.to_datetime(costs['dt'])

profiles.head()
# Out:
#     user_id            first_ts     channel  device         region  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States
#
#            dt      month  payer  acquisition_cost
# 0  2019-05-07 2019-05-01   True          1.088172
# 1  2019-07-09 2019-07-01  False          1.107237
# 2  2019-10-01 2019-10-01  False          0.000000
# 3  2019-08-22 2019-08-01  False          0.988235
# 4  2019-10-02 2019-10-01  False          0.230769

# %% [markdown]
# Определим максимальную и минимальную дату привлечения.

# %%
min_acquisition_date = profiles['dt'].min()
max_acquisition_date = profiles['dt'].max()

print(min_acquisition_date, max_acquisition_date)
# Out:
# 2019-05-01 2019-10-27

# %% [markdown]
# Предоставленные данные охватытвают промежуток с 1 мая по 27 октября 2019 года.

# %% [markdown]
# Выясним, из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей.

# %%
top_countries = (profiles
                 .groupby('region')
                 .agg({
                        'user_id': 'count',
                        'payer': 'sum'
                     })
                 .rename(columns={'user_id': 'total_users', 'payer': 'total_payers'})
                 .sort_values(by='total_users', ascending=False)
                )
top_countries
# Out:
#                total_users  total_payers
# region
# United States       100002          6902
# UK                   17575           700
# France               17450           663
# Germany              14981           616

# %% [markdown]
# Пользователи приложения приходят из США, Великобритании, Франции и Германии. Лидером по количеству платящих пользователей является США.
#
# Определим доли платящих пользователей по странам.

# %%
top_countries['total_payers_proportion'] = top_countries['total_payers'] / top_countries['total_payers'].sum() * 100

top_countries['payers_propotion_per_country'] = top_countries['total_payers'] / top_countries['total_users'] * 100

top_countries
# Out:
#                total_users  total_payers  total_payers_proportion  \
# region
# United States       100002          6902                77.716473
# UK                   17575           700                 7.881995
# France               17450           663                 7.465376
# Germany              14981           616                 6.936156
#
#                payers_propotion_per_country
# region
# United States                      6.901862
# UK                                 3.982930
# France                             3.799427
# Germany                            4.111875

# %% [markdown]
# Около 77.7% от всех платящих пользователей приложения приходится на пользователей из США. Из Великобритании, Франции и Германии  пришло 7.9%, 7.5% и 6.9% платящих пользователей соотвественно.
#
# Наибольшая доля платящих пользователей наблюдается в США: около 6.9% от всех зарегистрированных в этой стране пользователей совершили покупку. Доли в Великобритании, Франции и Герминии ниже и примерно равны: 4%, 3.8% и 4.1% соотвественно.

# %% [markdown]
# Узнаем, какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи.

# %%
top_devices = (profiles
                 .groupby('device')
                 .agg({
                        'user_id': 'count',
                        'payer': 'sum'
                     })
                 .rename(columns={'user_id': 'total_users', 'payer': 'total_payers'})
                 .sort_values(by='total_users', ascending=False)
                )

top_devices['total_payers_proportion'] = top_devices['total_payers'] / top_devices['total_payers'].sum() * 100

top_devices['payers_propotion_per_device'] = top_devices['total_payers'] / top_devices['total_users'] * 100


top_devices
# Out:
#          total_users  total_payers  total_payers_proportion  \
# device
# iPhone         54479          3382                38.081297
# Android        35032          2050                23.082986
# PC             30455          1537                17.306610
# Mac            30042          1912                21.529107
#
#          payers_propotion_per_device
# device
# iPhone                      6.207897
# Android                     5.851793
# PC                          5.046790
# Mac                         6.364423

# %% [markdown]
# Клиенты используют следующие устройства: IPhone, Andriod, PC, Mac. Самое распространенное устройство среди платящих пользователей - IPhone, им пользуется 38% платящих пользователей. Далее следуют Andriod, Mac и PC: ими пользуются 23%, 21.6% и 17.3% платящих пользователей соотвественно.

# %% [markdown]
# Наиболее активно начинают платить владельцы Mac и IPhone: покупателями становятся 6.4% и 6.2% пользователей-владельцев этих устройств. У пользователей с Android этот показатель равен  5.9%, у PC показатель меньше всего - 5.0%

# %% [markdown]
# Изучим рекламные источники привлечения и определим каналы, из которых пришло больше всего платящих пользователей.

# %%
top_channels = (profiles
                 .groupby('channel')
                 .agg({
                        'user_id': 'count',
                        'payer': 'sum'
                     })
                 .rename(columns={'user_id': 'total_users', 'payer': 'total_payers'})
                 .sort_values(by='total_payers', ascending=False)
                )

top_channels['total_payers_proportion'] = top_channels['total_payers'] / top_channels['total_payers'].sum() * 100

top_channels['payers_propotion_per_channel'] = top_channels['total_payers'] / top_channels['total_users'] * 100

top_channels
# Out:
#                     total_users  total_payers  total_payers_proportion  \
# channel
# FaceBoom                  29144          3557                40.051796
# TipTop                    19561          1878                21.146267
# organic                   56439          1160                13.061592
# WahooNetBanner             8553           453                 5.100777
# AdNonSense                 3880           440                 4.954397
# RocketSuperAds             4448           352                 3.963518
# LeapBob                    8553           262                 2.950118
# OppleCreativeMedia         8605           233                 2.623578
# lambdaMediaAds             2149           225                 2.533498
# YRabbit                    4312           165                 1.857899
# MediaTornado               4364           156                 1.756559
#
#                     payers_propotion_per_channel
# channel
# ...

# %% [markdown]
# Больше всего пришло платящих пользователей из каналов FaceBoom, TipTop: 40% и 21.1% соотвественно. Также 13.1% от всех платящих пользователей - "органические".
#
# Доля платящих пользователей наибольшая у каналов FaceBoom, AdNonSense и lambdaMediaAds: 12.2%, 11.3% и 10.5%. Меньше всего совершают первую покупку органические пользователи: всего 2.1%.

# %% [markdown]
# ### Маркетинг
#
# - Посчитайте общую сумму расходов на маркетинг.
# - Выясните, как траты распределены по рекламным источникам, то есть сколько денег потратили на каждый источник.
# - Постройте график с визуализацией динамики изменения расходов во времени по неделям по каждому источнику. Затем на другом графике визуализируйте динамику изменения расходов во времени по месяцам по каждому источнику.
# - Узнайте, сколько в среднем стоило привлечение одного пользователя (CAC) из каждого источника. Используйте профили пользователей.
#
# Напишите промежуточные выводы.

# %% [markdown]
# Посчитаем общую сумму расходов на маркетинг.

# %%
total_cost = costs['costs'].sum()

total_cost
# Out:
# 105497.30000000002

# %% [markdown]
# Общая сумма расходов на маркетинг за период с 1 мая по 27 октября 2019 года составила 105497.3 долларов.

# %% [markdown]
# Выясним, как траты распределены по рекламным источникам.

# %%
channels_cost = (costs
                 .groupby('channel')
                 .agg({
                     'costs': 'sum'
                 })
                 .sort_values(by='costs', ascending=False)
                )

channels_cost
# Out:
#                        costs
# channel
# TipTop              54751.30
# FaceBoom            32445.60
# WahooNetBanner       5151.00
# AdNonSense           3911.25
# OppleCreativeMedia   2151.25
# RocketSuperAds       1833.00
# LeapBob              1797.60
# lambdaMediaAds       1557.60
# MediaTornado          954.48
# YRabbit               944.22

# %% [markdown]
# Больше всего денег было потрачено на каналы TipTop и FaceBoom, 54751.3 и 32445.6 долларов соотвественно.

# %% [markdown]
# Построим график с визуализацией динамики изменения расходов во времени по неделям по каждому источнику. Затем на другом графике визуализируем динамику изменения расходов во времени по месяцам по каждому источнику.

# %%
costs['week'] = costs['dt'].values.astype('datetime64[W]')
costs['month'] = costs['dt'].values.astype('datetime64[M]')

costs.pivot_table(index='week', columns='channel', values='costs', aggfunc='sum').plot(figsize=(10,7), grid=True)
plt.title('Расходы на маркетинг по неделям')
plt.xlabel('Недели')
plt.ylabel('Расходы, $')
plt.show()

# %%
costs.pivot_table(index='month', columns='channel', values='costs', aggfunc='sum').plot(figsize=(10,7), grid=True)
plt.title('Расходы на маркетинг по месяцам')
plt.xlabel('Месяцы')
plt.ylabel('Расходы, $')
plt.show()

# %% [markdown]
# Можем сделать вывод, что до начала октября траты компании на маркетинг росли, в особенности на каналы TipTop и FaceBoom.

# %% [markdown]
# Узнаем, сколько в среднем стоило привлечение одного пользователя (CAC) из каждого источника.

# %%
channels_cac = (profiles
                .groupby('channel')
                .agg({'acquisition_cost': 'mean'})
                .sort_values(by='acquisition_cost', ascending=False)
               )
channels_cac
# Out:
#                     acquisition_cost
# channel
# TipTop                      2.799003
# FaceBoom                    1.113286
# AdNonSense                  1.008054
# lambdaMediaAds              0.724802
# WahooNetBanner              0.602245
# RocketSuperAds              0.412095
# OppleCreativeMedia          0.250000
# YRabbit                     0.218975
# MediaTornado                0.218717
# LeapBob                     0.210172
# organic                     0.000000

# %% [markdown]
# Самым дорогим источником в плане стоимости привлечения одного пользователя является канал TipTop: в среднем один пользователь из этого источника обошелся компании в 2.8 долларов. За ним следуют каналы FaceBoom и AdNonScene со средней стоимостью привлечения пользователей в 1.1 и 1 доллара соотвественно.
# </br>Самыми дешевыми оказались пользователи с каналов YRabbiе, MediaTornado, LeapBob: в среднем один пользователь из этих источников обошелся примерно в 0.2 доллара. Пользователей, пришедших органически, считаем бесплатными, поскольку компания не потратила денег на их привлечение.

# %% [markdown]
# ### Оцените окупаемость рекламы
#
# Используя графики LTV, ROI и CAC, проанализируйте окупаемость рекламы. Считайте, что на календаре 1 ноября 2019 года, а в бизнес-плане заложено, что пользователи должны окупаться не позднее чем через две недели после привлечения. Необходимость включения в анализ органических пользователей определите самостоятельно.
#
# - Проанализируйте окупаемость рекламы c помощью графиков LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Проверьте конверсию пользователей и динамику её изменения. То же самое сделайте с удержанием пользователей. Постройте и изучите графики конверсии и удержания.
# - Проанализируйте окупаемость рекламы с разбивкой по устройствам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Проанализируйте окупаемость рекламы с разбивкой по странам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Проанализируйте окупаемость рекламы с разбивкой по рекламным каналам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Ответьте на такие вопросы:
#     - Окупается ли реклама, направленная на привлечение пользователей в целом?
#     - Какие устройства, страны и рекламные каналы могут оказывать негативное влияние на окупаемость рекламы?
#     - Чем могут быть вызваны проблемы окупаемости?
#
# Напишите вывод, опишите возможные причины обнаруженных проблем и промежуточные рекомендации для рекламного отдела.

# %% [markdown]
# В анализ не будем включать органических пользователей, поскольку для компании они бесплатны, так как пришли в приложение без рекламы.

# %% [markdown]
# #### **Проанализируем окупаемость рекламы c помощью графиков LTV и ROI, а также графики динамики LTV, CAC и ROI.**

# %%
horizon = 14
observation_date = datetime(2019,11,1).date()
profiles_filtered = profiles.query('channel != "organic"')

ltv_raw, ltv_grouped, ltv_in_time, roi_grouped, roi_in_time = get_ltv(profiles_filtered, orders, observation_date, horizon)

plot_ltv_roi(ltv_grouped, ltv_in_time, roi_grouped, roi_in_time, horizon, window=7)

# %% [markdown]
# Судя по графикам LTV и ROI первые две недели доход от привлеченных пользователей в среднем растет, однако так и не достигает уровня окупаемости.
#
# Если расматривать график диманики CAC, то можно заметить постоянное увеличиение трат компании на маркетинг на протяжение всего периода. Практически всё время наблюдается падение показателя ROI на графикие динамики этого показателя. Начиная со второй половины июня реклама перестаёт окупаться.
#
# Значение LTV 14-го дня на протяжение всего перирода наблюдений стабильно колеблется в диапазоне от 0.8 до 1.1 долларов.

# %% [markdown]
# #### **Проверим конверсию пользователей и динамику её изменения. То же самое сделаем с удержанием пользователей.**

# %%
conversion_raw, conversion_grouped, conversion_in_time = get_conversion(profiles_filtered, orders, observation_date, horizon)

plot_conversion(conversion_grouped, conversion_in_time, horizon, window=14)

# %% [markdown]
# В первый день после регистрации покупку совершило около 6% покупателей, а концу второй недели этот показатель вырос до 8%.
#
# График динамики конверсии на 14-й день показывает, что этот показатель весь период наблюдения держался в границах от 7.5% до 8.5%.

# %%
retention_raw, retention_grouped, retention_in_time = get_retention(profiles_filtered, visits, observation_date, horizon)

plot_retention(retention_grouped, retention_in_time, horizon, window=14)

# %% [markdown]
# Удержание платящих пользователей ожидаемо выше неплатящих. Удержание платящих пользователей в 1-й день составляет около 36%, а в 14-й - около 10%, в то время как удержание неплатящих пользователей уже в 1-й день уже составляет лишь 17%, а к 14-му дню оно практически достигает нуля.
#
# Динамики удержания платящих и неплатящих пользователей на 14-й день на всем периоде наблюдений стабильны: удержание платящих пользователей в среднем колеблется между 8% и 15%, неплатящих - не превосходит 1% весь период.

# %% [markdown]
# #### **Проанализируем окупаемость рекламы с разбивкой по устройствам.**

# %%
horizon = 14
observation_date = datetime(2019,11,1).date()

ltv_raw, ltv_grouped, ltv_in_time, roi_grouped, roi_in_time = get_ltv(profiles_filtered, orders, observation_date, horizon, dimensions=['device'])

plot_ltv_roi(ltv_grouped, ltv_in_time, roi_grouped, roi_in_time, horizon, window=14)

# %% [markdown]
# LTV у всех устройств растет одинаково на протяжении первых двух недель, однако график ROI показывает, что в среднем уровня окупаемости достигает лишь PC, реклама для устройств IPhone, Andriod и Mac не окупается.
#
# График динамики LTV показывает, что средний LTV 14-го дня для всех устройств на протяжении всего периода наблюдения колеблется в рамках 0.6-1.2 долларов.
#
# Больше информации дают графики дикамики CAC и ROI: с начала июня траты на рекламу для всех видов устройств начинают расти, причем траты на устройства IPhone и Mac заметно выше трат на Andriod и PC. На графике динамики ROI 14-го дня в этот же период наблюдается спад показателей, в середине июня перестают окупаться траты на рекламу на устройствах IPhone, PC и Mac. К концу периода наблюдения траты перестают окупаться уже на всех устройствах.

# %% [markdown]
# #### **Проанализируем окупаемость рекламы с разбивкой по странам.**

# %%
horizon = 14
observation_date = datetime(2019,11,1).date()

ltv_raw, ltv_grouped, ltv_in_time, roi_grouped, roi_in_time = get_ltv(profiles_filtered, orders, observation_date, horizon, dimensions=['region'])

plot_ltv_roi(ltv_grouped, ltv_in_time, roi_grouped, roi_in_time, horizon, window=14)

# %% [markdown]
# По графикам видно, что средний LTV американских пользователей заметно выше пользователей других стран - американцы тратят деньги на приложение больше европейцев. В динамике показатель LTV американских пользователей не только выше европейских, но и более стабилен. Однако, судя по графику ROI, не окупаются именно траты на американских пользователей.
#
# График динамики CAC показывает, что траты на рекламу для американских пользователей гораздо выше остальных: если на европейских пользователей компания тратит около 0.4 доллара за человека, то на одного американского пользоваталя за полгода наблюдений траты выросли с 0.8 до почти 1.8 долларов. Из-за этого показатель ROI 14-го дня для американцев упал ниже уровня окупаемости уже в июне, в то время как траты на пользователей из Европы стабильно окупаются, их показатель ROI в основном держится на уровне 1.5-2.
#
# Можно сделать вывод, что американские пользователи приносят компании больше денег, однако компания тратит на их привлечение так много стредств, что траты на рекламу в США просто не окупаются. В то же время пользователи из европейских стран приносят компании в среднем хоть и меньше денег, но стоимость их привлечения гораздо ниже американских пользователей, что делает их более выгодными для компании с точки зрения окупаемости рекламы.

# %% [markdown]
# #### **Проанализируем окупаемость рекламы с разбивкой по рекламным каналам.**

# %%
horizon = 14
observation_date = datetime(2019,11,1).date()

ltv_raw, ltv_grouped, ltv_in_time, roi_grouped, roi_in_time = get_ltv(profiles_filtered, orders, observation_date, horizon, dimensions=['channel'])

plot_ltv_roi(ltv_grouped, ltv_in_time, roi_grouped, roi_in_time, horizon, window=21)

# %% [markdown]
# График LTV показывает, что в среднем больше всего платят пользователи, привлеченные каналами lambdaMediaAds и TipTop: 1.7 и 1.5 долларов соотвественно. График динамики LTV также демонстрирует, что пользователи из этих источников стабильно платят больше других пользователей.
#
# Но по графику ROI и его динамики видно, что уровня окупаемости не достигают три источника: AdNonScene, FaceBoom и TipTop - именно из этих источников в приложение пришло наибольшее количество пользователей, но, оказывается, траты на этих пользователей стабильно не окупаются. График динамики CAC показывает, что пользователи из этих каналов - самые дорогие для компании, но больше всех выделяется канал TipTop: траты на привлечение одного пользователя через этот источник сильно выросли за полгода, с 1 до 3.5 долларов.
#
# Можно сделать вывод, что через каналы TipTop, FaceBoom, AdNonScene компания привлекла около 65% своих платящих пользователей, однако стоимость их привлечения оказалась так велика, что траты именно на этих пользователей не окупились, что привело к убыткам компании.

# %% [markdown]
# Также можно отметить, что график динамики стоимости привлечения пользователей через канал TipTop походит на график динамики стоимости привлечения по США. Вероятно, TipTop занимается привлечением пользователей только в этой стране, что объяснит столь низкий показатель ROI у США. Проверим это.

# %%
tiptop_countries = (profiles
                    .query('channel == "TipTop"')
                    .groupby('region')
                    .agg({'user_id': 'count'})
                   )
tiptop_countries
# Out:
#                user_id
# region
# United States    19561

# %%
profiles.groupby(['region', 'channel']).agg({'user_id': 'count'}).sort_values(by='user_id', ascending=False)
# Out:
#                                   user_id
# region        channel
# United States organic               38173
#               FaceBoom              29144
#               TipTop                19561
# UK            organic                6421
# France        organic                6392
# Germany       organic                5453
# United States RocketSuperAds         4448
#               MediaTornado           4364
#               YRabbit                4312
# UK            OppleCreativeMedia     3052
#               LeapBob                3046
#               WahooNetBanner         3003
# France        OppleCreativeMedia     2991
#               LeapBob                2988
#               WahooNetBanner         2971
# Germany       WahooNetBanner         2579
#               OppleCreativeMedia     2562
#               LeapBob                2519
# France        AdNonSense             1366
# UK            AdNonSense             1295
# Germany       AdNonSense             1219
# ...

# %%
for channel in top_channels.index.tolist():
    channel_in_countries = (profiles
                    .query('channel == @channel')
                    .groupby('region')
                    .agg({'user_id': 'count'})
                    .sort_values(by='user_id', ascending=False)
                    .rename(columns={'user_id': channel})
                   )
    display(channel_in_countries)
# Out:
#                FaceBoom
# region
# United States     29144
#                TipTop
# region
# United States   19561
#                organic
# region
# United States    38173
# UK                6421
# France            6392
# Germany           5453
#          WahooNetBanner
# region
# UK                 3003
# France             2971
# Germany            2579
#          AdNonSense
# region
# France         1366
# UK             1295
# Germany        1219
#                RocketSuperAds
# region
# United States            4448
#          LeapBob
# region
# UK          3046
# France      2988
# Germany     2519
#          OppleCreativeMedia
# region
# UK                     3052
# France                 2991
# Germany                2562
#          lambdaMediaAds
# region
# UK                  758
# France              742
# Germany             649
#                YRabbit
# region
# United States     4312
#                MediaTornado
# region
# United States          4364

# %% [markdown]
# Как стало видно, все самые "дорогие" каналы - TipTop и FaceBoom - нацелены исключительно на американских пользователей.

# %% [markdown]
# Возможно, TipTop также отвественнен за высокие показатели стоимости привлечения пользователей с IPhone и Mac. Также проверим это.

# %%
tiptop_devices = (profiles
                    .query('channel == "TipTop"')
                    .groupby('device')
                    .agg({'user_id': 'count'})
                    .sort_values(by='user_id', ascending=False)
                   )
tiptop_devices
# Out:
#          user_id
# device
# iPhone      8840
# Mac         4820
# Android     3889
# PC          2012

# %% [markdown]
# Делаем вывод, что данный канал привлечения также повлиял на рост стоимости привлечения пользователей для всех устройств.

# %% [markdown]
# #### **Проанализируем конверсию и удержание по каналам.**

# %%
conversion_raw, conversion_grouped, conversion_in_time = get_conversion(profiles_filtered, orders, observation_date, horizon, dimensions=['channel'])
retention_raw, retention_grouped, retention_in_time = get_retention(profiles_filtered, visits, observation_date, horizon, dimensions=['channel'])

plot_conversion(conversion_grouped, conversion_in_time, horizon, window=7)
plot_retention(retention_grouped, retention_in_time, horizon, window=7)

# %% [markdown]
# Ожидаемо, наибольшие показатели конверсии имеют каналы FaceBoom, AdNonSense, lambdaMediaAds и TipTop. Однако AdNoSense и FaceBoom показывают низкие показатели удержания платящих пользователей: ко концу второй недели приложением пользовалось менее 5% пользователей, пришедших из этих источников, в то время как у остальных каналов этот показатель не меньше 10%. Получается, новые пользователи из каналов AdNoSense и FaceBoom конвертируются лучше, но хуже удерживаются после первой покупки.
#
# Удержание неплатящих пользователей заметно ниже платящих для всех каналов.

# %% [markdown]
# #### **Проанализируем конверсию и удержание по странам.**

# %%
conversion_raw, conversion_grouped, conversion_in_time = get_conversion(profiles_filtered, orders, observation_date, horizon, dimensions=['region'])
retention_raw, retention_grouped, retention_in_time = get_retention(profiles_filtered, visits, observation_date, horizon, dimensions=['region'])

plot_conversion(conversion_grouped, conversion_in_time, horizon, window=7)
plot_retention(retention_grouped, retention_in_time, horizon, window=7)

# %% [markdown]
# По графикам можно сделать вывод, что пользователи из США лучше конвертируются в покупателей, однако их удержание после покупки заметно хуже удержания тех же платящих пользователей из Европы. К концу второй недели в США конвертировалось около 10% пользователей, но среди платящих пользователей удержалось всего 10%, в европейских странах: конвертируется всего около 5%, но удерживается к концу второй недели 15-17%.

# %% [markdown]
# #### **Проанализируем конверсию и удержание по устройствам.**

# %%
conversion_raw, conversion_grouped, conversion_in_time = get_conversion(profiles_filtered, orders, observation_date, horizon, dimensions=['device'])
retention_raw, retention_grouped, retention_in_time = get_retention(profiles_filtered, visits, observation_date, horizon, dimensions=['device'])

plot_conversion(conversion_grouped, conversion_in_time, horizon, window=7)
plot_retention(retention_grouped, retention_in_time, horizon, window=7)

# %% [markdown]
# Среди устройств показатель конвертации хуже всего у PC: 6.5%, в то время как у остальных видов устройств 8-8.5%. Удержание у PC чуть выше остальных устройств, но у всех устройств к концу второй недели удержание практически одинаковое  - около 10%.

# %% [markdown]
# **Ответим на важные для компании вопросы.**

# %% [markdown]
#  1. Реклама, направленная на привлечение пользователей в целом, не окупается. На это указывают графики ROI и его динамики: в среднем к 14-му дню после регистрации показатель ROI не достигает уровня окупаемости, а в динамике ROI 14-го дня опустился ниже уровня окупаемости в июле 2019 года, после чего не поднимался выше него.
#
#  2. Выявлены следующие факторы, негативно влияющие на окупаемость рекламы:
#  - Траты на рекламу для устройств IPhone и Mac слишком велики и не окупаются.
#  - Пользователи из США в среднем приносят компании больше денег, чем пользователи из других стран, однако траты на их привлечение не окупаются.
#  - Траты на каналы привлечения TipTop, FaceBoom, AdNonSense не окупаются.
#  - Каналы FaceBoom и AdNonSense привлекают лучше конвертирующихся пользователей, однако те хуже удерживаются.
#
#  3. Проблемы окупаемости могли быть вызваны чрезмерно большой стоимостью привлечения пользователей через канал TipTop: этот канал привлёк в приложение наибольшее число платящих клиентов (40%), однако из-за высокой стоимости привлечения они все становятся невыгодными для компании.

# %% [markdown]
# ### Напишем выводы
#
# - Выделите причины неэффективности привлечения пользователей.
# - Сформулируйте рекомендации для отдела маркетинга.

# %% [markdown]
# Проведен маркетинговый анализ приложения ProcrastinatePro+. Использованы предоставленные компанией данные о покупках пользователей в период с 1 мая по 27 октября 2019 года: лог сервера с данными об их посещениях, выгрузка их покупок за этот период, рекламные расходы. Данные не имеют пропусков значений и дубликатов строк.
#
# В ходе исследовательского анализа было выявлено:
# - Пользователи приложения приходят из США, Великобритании, Франции и Германии. Около 77.7% от всех платящих пользователей приложения приходится на пользователей из США. Доли платящих пользователей из Великобритании, Франции и Германии почти одинаковы и равны 7.9%, 7.5% и 6.9% соотвественно.
# - Клиенты используют следующие устройства: IPhone, Andriod, PC, Mac. Самое распространенное устройство среди платящих пользователей - IPhone, им пользуется 38% платящих пользователей. Далее следуют Andriod, Mac и PC: ими пользуются 23%, 21.6% и 17.3% платящих пользователей соотвественно.
# - Больше всего пришло платящих пользователей из каналов FaceBoom, TipTop. Доли платящих пользователей из этих каналов составляют 40% и 21.1% соотвественно. Также 13.1% от всех платящих пользователей - "органические".
#
# Результаты маркетингового анализа:
# - Общая сумма расходов на маркетинг за период с 1 мая по 27 октября 2019 года составила 105497.3 долларов.
# - Больше всего денег было потрачено на каналы TipTop и FaceBoom, 54751.3 и 32445.6 долларов соотвественно.
# - До начала октября траты компании на маркетинг росли, в особенности на каналы TipTop и FaceBoom.
# - Самым дорогим источником в плане стоимости привлечения одного пользователя является канал TipTop: в среднем один пользователь из этого источника обошелся компании в 2.8 долларов. За ним следуют каналы FaceBoom и AdNonSense со средней стоимостью привлечения пользователей в 1.1 и 1 доллара соотвественно.
# - Самыми дешевыми оказались пользователи с каналов YRabbiе, MediaTornado, LeapBob: в среднем один пользователь из этих источников обошелся примерно в 0.2 доллара. Пользователей, пришедших органически, считаем бесплатными, поскольку компания не потратила денег на их привлечение.
#
# При оценке окупаемости рекламной кампании приложение не включались пользователи, пришедшие органически, поскольку они пришли без рекламы и по сути бесплатны для компании.
#
# Анализ окупаемости по всем пользователям дал следующие результаты:
# - Судя по графикам LTV и ROI первые две недели доход от привлеченных пользователей в среднем растет, однако так и не достигает уровня окупаемости.
# - При изучении графика диманики CAC замечено постоянное увеличиение трат компании на маркетинг на протяжение всего периода. Практически всё время наблюдается падение показателя ROI на графикие динамики этого показателя. Начиная со второй половины июня реклама перестаёт окупаться.
# - Значение LTV 14-го дня на протяжение всего перирода наблюдений стабильно колеблется в диапазоне от 0.8 до 1.1 долларов.
# - В первый день после регистрации покупку совершило около 6% покупателей, а концу второй недели этот показатель вырос до 8%.
# - График динамики конверсии на 14-й день показывает, что этот показатель весь период наблюдения держался в границах от 7.5% до 8.5%.
#
# Анализ окупаемости рекламы с разбивкой по устройствам дал следующие результаты:
# - LTV у всех устройств растет одинаково на протяжении первых двух недель, однако график ROI показывает, что в среднем уровня окупаемости достигает лишь PC, реклама для устройств IPhone, Andriod и Mac не окупается.
# - График динамики LTV показывает, что средний LTV 14-го дня для всех устройств на протяжении всего периода наблюдения колеблется в рамках 0.6-1.2 долларов.
# - Графики дикамики CAC и ROI показывают, что с начала июня траты на рекламу для всех видов устройств начинают расти, причем траты на устройства IPhone и Mac заметно выше трат на Andriod и PC. На графике динамики ROI 14-го дня в этот же период наблюдается спад показателей, в середине июня перестают окупаться траты на рекламу на устройствах IPhone, PC и Mac. К концу периода наблюдения траты перестают окупаться уже на всех устройствах.
#
# Анализ окупаемости рекламы с разбивкой по странам дал следующие результаты:
# - По графикам видно, что средний LTV американских пользователей заметно выше пользователей других стран - американцы тратят деньги на приложение больше европейцев. В динамике показатель LTV американских пользователей не только выше европейских, но и более стабилен. Однако, судя по графику ROI, не окупаются именно траты на американских пользователей.
#
# - График динамики CAC показывает, что траты на рекламу для американских пользователей гораздо выше остальных: если на европейских пользователей компания тратит около 0.4 доллара за человека, то на одного американского пользоваталя за полгода наблюдений траты выросли с 0.8 до почти 1.8 долларов. Из-за этого показатель ROI 14-го дня для американцев упал ниже уровня окупаемости уже в июне, в то время как траты на пользователей из Европы стабильно окупаются, их показатель ROI в основном держится на уровне 1.5-2.
#
# Выяснилось, что американские пользователи приносят компании больше денег, однако компания тратит на их привлечение так много стредств, что траты на рекламу в США просто не окупаются. В то же время пользователи из европейских стран приносят компании в среднем хоть и меньше денег, но стоимость их привлечения гораздо ниже американских пользователей, что делает их более выгодными для компании с точки зрения окупаемости рекламы.
#
# Анализ окупаемости рекламы с разбивкой по каналам привлечения дал следующие результаты:
# - График LTV показывает, что в среднем больше всего платят пользователи, привлеченные каналами lambdaMediaAds и TipTop: 1.7 и 1.5 долларов соотвественно. График динамики LTV также демонстрирует, что пользователи из этих источников стабильно платят больше других пользователей.
# - Но по графику ROI и его динамики видно, что уровня окупаемости не достигают три источника: AdNonSense, FaceBoom и TipTop - именно из этих источников в приложение пришло наибольшее количество пользователей, но, оказывается, траты на этих пользователей стабильно не окупаются. График динамики CAC показывает, что пользователи из этих каналов - самые дорогие для компании, но больше всех выделяется канал TipTop: траты на привлечение одного пользователя через этот источник сильно выросли за полгода, с 1 до 3.5 долларов.
# - Можно сделать вывод, что через каналы TipTop, FaceBoom, AdNonSense компания привлекла около 65% своих платящих пользователей, однако стоимость их привлечения оказалась так велика, что траты именно на этих пользователей не окупились, что привело к убыткам компании.
#
# Выявлено, что TipTop занимается привлечением пользователей только в США, что объясняет столь низкий показатель ROI у этой страны. Аналогично, траты на этот канал привлечения повлиял на стоимость привлечения одного пользователя по всем видам устройств. Также только на США нацелен и другой "дорогой" канал - FaceBoom.
#
# Также были проведен анализ конверсии и удержания по каналам, странам и устройствам. Было выялвено следующее:
# - Наибольшие показатели конверсии имеют каналы FaceBoom, AdNonSense, lambdaMediaAds и TipTop. Однако AdNoSense и FaceBoom показывают низкие показатели удержания платящих пользователей: ко концу второй недели приложением пользовалось менее 5% пользователей, пришедших из этих источников, в то время как у остальных каналов этот показатель не меньше 10%. Получается, новые пользователи из каналов AdNoSense и FaceBoom конвертируются лучше, но хуже удерживаются после первой покупки.
# - Пользователи из США лучше конвертируются в покупателей, однако их удержание после покупки заметно хуже удержания тех же платящих пользователей из Европы. К концу второй недели в США конвертировалось около 10% пользователей, но среди платящих пользователей удержалось всего 10%, в европейских странах: конвертируется всего около 5%, но удерживается к концу второй недели 15-17%.
# - Среди устройств показатель конвертации хуже всего у PC: 6.5%, в то время как у остальных видов устройств 8-8.5%. Удержание у PC чуть выше остальных устройств, но у всех устройств к концу второй недели удержание практически одинаковое - около 10%.
#
# Можно сделать следующие выводы:
#
#  1. Реклама, направленная на привлечение пользователей в целом, не окупается. На это указывают графики ROI и его динамики: в среднем к 14-му дню после регистрации показатель ROI не достигает уровня окупаемости, а в динамике ROI 14-го дня опустился ниже уровня окупаемости в июле 2019 года, после чего не поднимался выше него.
#
#  2. Выявлены следующие факторы, негативно влияющие на окупаемость рекламы:
#  - Траты на рекламу для устройств IPhone и Mac слишком велики и не окупаются.
#  - Пользователи из США в среднем приносят компании больше денег, чем пользователи из других стран, однако траты на их привлечение не окупаются.
#  - Траты на каналы привлечения TipTop, FaceBoom, AdNonSense не окупаются.
#  - Каналы FaceBoom и AdNonSense привлекают лучше конвертирующихся пользователей, однако те хуже удерживаются.
#
#  3. Проблемы окупаемости могли быть вызваны чрезмерно большой стоимостью привлечения пользователей через канал TipTop: этот канал привлёк в приложение наибольшее число платящих клиентов (40%), однако из-за высокой стоимости привлечения они все становятся невыгодными для компании.
#
# Рекомендации для отдела маркетинга:
# 1. Пересмотреть траты на каналы привлечения TipTop, FaceBoom, AdNonSense и рассмотреть другие, например, lambdaMediaAds, YRabbit, MediaTornado - траты на эти каналы стабильно окупаются и их стоимость заметно ниже.
# 2. Рассмотреть большее привлечение пользователей из стран Европы: траты на пользователей Германии, Франции и Англии стабильно окупаются.
# 3. Стоит также уделить внимание на привлечение в приложение владельцев Android и PC. Пользователи этих устройств тратят в среднем столько же денег в приложении, как и владельцы IPhone и Mac.
